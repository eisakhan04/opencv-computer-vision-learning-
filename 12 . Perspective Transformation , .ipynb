# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the project contributions
contributions = [
    "Improved Traffic Management",
    "Automation of Traffic Enforcement",
    "Driver Safety Enhancement",
    "Traffic Flow Optimization",
    "E-Challan System",
    "Data-Driven Decision Making",
    "Scalable Infrastructure",
    "Integration with Smart City Infrastructure",
    "Support for Law Enforcement"
]

values = [9, 8, 7, 8, 6, 9, 7, 8, 9]  # Assigning values to represent contribution impact

# Create a DataFrame
import pandas as pd
df = pd.DataFrame({
    'Contribution': contributions,
    'Impact': values
})

# Set the style for the plot
sns.set(style="whitegrid")

# Create the bar plot
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Impact', y='Contribution', data=df, palette='Blues_d')

# Add title and labels
plt.title('Contributions of the Project', fontsize=16)
plt.xlabel('Impact Level', fontsize=12)
plt.ylabel('Contributions', fontsize=12)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data for the project contributions
contributions = [
    "Improved Traffic Management",
    "Automation of Traffic Enforcement",
    "Driver Safety Enhancement",
    "Traffic Flow Optimization",
    "E-Challan System",
    "Data-Driven Decision Making",
    "Scalable Infrastructure",
    "Integration with Smart City Infrastructure",
    "Support for Law Enforcement"
]

values = [9, 8, 7, 8, 6, 9, 7, 8, 9]  # Assigning values to represent contribution impact

# Create a DataFrame
df = pd.DataFrame({
    'Contribution': contributions,
    'Impact': values
})

# Set the style for the plot
sns.set(style="whitegrid")

# Create the bar plot
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Impact', y='Contribution', data=df, palette='Blues_d')

# Add title and labels
plt.title('Contributions of the Project', fontsize=16)
plt.xlabel('Impact Level', fontsize=12)
plt.ylabel('Contributions', fontsize=12)

# Save the plot as a PNG file
plt.savefig('project_contributions.jpg', format='jpg')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data for the project contributions
contributions = [
    "Improved Traffic Management",
    "Automation of Traffic Enforcement",
    "Driver Safety Enhancement",
    "Traffic Flow Optimization",
    "E-Challan System",
    "Data-Driven Decision Making",
    "Scalable Infrastructure",
    "Integration with Smart City Infrastructure",
    "Support for Law Enforcement"
]

values = [9, 8, 7, 8, 6, 9, 7, 8, 9]  # Assigning values to represent contribution impact

# Create a DataFrame
df = pd.DataFrame({
    'Contribution': contributions,
    'Impact': values
})

# Set the style for the plot
sns.set(style="whitegrid")

# Create the bar plot
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Impact', y='Contribution', data=df, palette='Blues_d')

# Add title and labels
plt.title('Contributions of the Project', fontsize=16)
plt.xlabel('Impact Level', fontsize=12)
plt.ylabel('Contributions', fontsize=12)

# Use tight_layout to ensure everything fits within the figure
plt.tight_layout()

# Save the plot as a PNG file
plt.savefig('project_contributions_full.png', format='png')

# Show the plot
plt.show()

# %% [markdown]
# # Perspective Transformation OpenCV

# %%
import cv2 
import numpy as np

# %%
img = cv2.imread("bill.jpeg")


cv2.circle(img , (15 , 190),4 , (0,0,255) , -1)
cv2.circle(img , (1126,140),4 , (0,0,255) , -1)
cv2.circle(img , (1184 ,1444 ),4 , (0,0,255) , -1)
cv2.circle(img , (40 ,1497),4 , (0,0,255) , -1)
print(img.shape)

cv2.imshow("Eisa ",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1599, 1200, 3)

# %%
# src1 = np.float32([[15,190],[1126,140],[1184 ,1444],[40 ,1497]])
# src1
# Out:
# array([[  15.,  190.],
#        [1126.,  140.],
#        [1184., 1444.],
#        [  40., 1497.]], dtype=float32)

# %%
img = cv2.imread("bill.jpeg")

w ,h = (1599, 1200)

src1 = np.float32([[15,190],[1126,140],[1184 ,1444],[40 ,1497]])
dst1 = np.float32([[0,0],[w,0],[0,h],[w,h]])
m = cv2.getPerspectiveTransform(src1 , dst1)
new_img = cv2.warpPerspective(img , m , (w,h))



cv2.imshow("new_img ",new_img)
cv2.imshow("Eisa ",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 28 , 190
# 1142,132
# 1184 ,1444 
# 40 ,1497

# %% [markdown]
# # Simple Threshold OpenCv
#
# Simple thresholding is a technique where pixels in an image are either set to a maximum value or to zero based on a threshold value you provide. OpenCV makes it easy to apply this technique.

# %%
import cv2
import numpy as np

# %%
img = cv2.imread("bill.jpeg")
img = cv2.resize( img,(600,300))

_, thresholded_image = cv2.threshold(img, 190,255, cv2.THRESH_BINARY)


cv2.imshow("thresholded_image ",thresholded_image)
cv2.imshow("Eisa ",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Import necessary libraries
import cv2
# img = cv2.imread("eisa.jpeg")
# Load the image in grayscale
image = cv2.imread('eisa.jpeg', cv2.IMREAD_GRAYSCALE)
image = cv2.resize( image,(500,600))
# Define a threshold value
threshold_value = 127
max_value = 255

# Apply simple thresholding
_, thresholded_image = cv2.threshold(image, threshold_value, max_value, cv2.THRESH_BINARY)

# Display the original and thresholded images
cv2.imshow("Original Image", image)
cv2.imshow("Thresholded Image", thresholded_image)

# Wait for a key press and close windows
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Import necessary libraries
import cv2

# Load the image in grayscale
image = cv2.imread('eisa.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply Otsu's binarization
# Note: We pass 0 as the threshold value since Otsu's method calculates it automatically
_, otsu_thresholded_image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Display the original and thresholded images
cv2.imshow("Original Image", image)
cv2.imshow("Otsu's Thresholding", otsu_thresholded_image)

# Wait for a key press and close windows
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Live Object Detection

# %% [markdown]
# # Huge transformation line

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread(r"C:\Users\Mega Computers\Downloads\download (2).png")
img = cv2.resize( img,(500,500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Edge detection
edges = cv2.Canny(gray, 50, 150, apertureSize=3)

# Hough Line Transform
lines = cv2.HoughLines(edges, 1, np.pi/180, 200)

# Draw the lines on the original image
for line in lines:
    rho, theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a * rho
    y0 = b * rho
    x1 = int(x0 + 1000 * (-b))
    y1 = int(y0 + 1000 * (a))
    x2 = int(x0 - 1000 * (-b))
    y2 = int(y0 - 1000 * (a))
    cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2)

cv2.imshow("Detected Lines", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread(r"C:\Users\Mega Computers\Downloads\download (2).png")
img = cv2.resize( img,(500,500))

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Edge detection
edges = cv2.Canny(gray, 50, 150, apertureSize=3)

# Probabilistic Hough Line Transform
lines = cv2.HoughLinesP(edges, 1, np.pi/180, 100, minLineLength=50, maxLineGap=10)

# Draw the lines on the original image
for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

cv2.imshow("Detected Lines", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Template Matching using Opencv

# %%
import cv2
import numpy as np

# Load the main image and template
main_image = cv2.imread(r"C:\Users\Mega Computers\Downloads\download (2).jpg")
template = cv2.imread(r"C:\Users\Mega Computers\Pictures\Screenshots\Screenshot 2024-11-16 233435.png", cv2.IMREAD_COLOR)

# Convert images to grayscale
main_gray = cv2.cvtColor(main_image, cv2.COLOR_BGR2GRAY)
template_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)

# Check if the template is larger than the main image
if template_gray.shape[0] > main_gray.shape[0] or template_gray.shape[1] > main_gray.shape[1]:
    scale_factor = min(main_gray.shape[0] / template_gray.shape[0], main_gray.shape[1] / template_gray.shape[1])
    template_gray = cv2.resize(template_gray, (int(template_gray.shape[1] * scale_factor), int(template_gray.shape[0] * scale_factor)))

# Get the dimensions of the resized template
w, h = template_gray.shape[::-1]

# Perform template matching
result = cv2.matchTemplate(main_gray, template_gray, cv2.TM_CCOEFF_NORMED)

# Find the location of the best match
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

# Draw a rectangle around the matched region
top_left = max_loc  # Best match position
bottom_right = (top_left[0] + w, top_left[1] + h)

cv2.rectangle(main_image, top_left, bottom_right, (0, 255, 0), 2)

# Show the result
cv2.imshow("Matched Image", main_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Hough Circle Detection

# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread(r"C:\Users\Mega Computers\Downloads\images (7).jpg")
image = cv2.resize( image,(500,500))

output = image.copy()

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply a Gaussian blur to reduce noise
gray_blurred = cv2.GaussianBlur(gray, (9, 9), 2)

# Detect circles using Hough Transform
circles = cv2.HoughCircles(
    gray_blurred, 
    cv2.HOUGH_GRADIENT, 
    dp=1, 
    minDist=20, 
    param1=20, 
    param2=40, 
    minRadius=0, 
    maxRadius=0
)

# If some circles are detected
if circles is not None:
    circles = np.uint16(np.around(circles))  # Round off values
    for circle in circles[0, :]:
        x, y, r = circle  # Extract circle parameters
        # Draw the circle
        cv2.circle(output, (x, y), r, (0, 255, 0), 3)
        # Draw the center of the circle
        cv2.circle(output, (x, y), 2, (0, 0, 255), 3)

# Show the result
cv2.imshow("Detected Circles", output)
cv2.waitKey(0)
cv2.destroyAllWindows()
