# %%
import numpy

# %%
import matplotlib

# %%
import pandas

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 75.7 kB/s eta 0:08:33
#    ---------------------------------------- 0.1/38.8 MB 176.6 kB/s eta 0:03:40
#    ---------------------------------------- 0.1/38.8 MB 176.6 kB/s eta 0:03:40
#    ---------------------------------------- 0.1/38.8 MB 176.6 kB/s eta 0:03:40
# ...

# %%
import cv2

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %%
import cv2
import sys

print(f"Python version: {sys.version}")
print(f"OpenCV version: {cv2.__version__}")
# Out:
# Python version: 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]
# OpenCV version: 4.10.0

# %%
path = r"C:\Users\Mega Computers\Pictures\chris-ried-sqJ40H9RtNw-unsplash.jpg"
img = cv2.imread(path)

cv2.imshow('image=' ,img)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
img = cv2.imread(path)

img = cv2.resize(img , (600 ,400))

cv2.imshow('image=' ,img)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import os

# %%
img_name = os.listdir(r'C:\Users\Mega Computers\Pictures\chris-ried-sqJ40H9RtNw-unsplash.jpg')
img_name
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 img_name = os.listdir(r'C:\Users\Mega Computers\Pictures\chris-ried-sqJ40H9RtNw-unsplash.jpg')
#       2 img_name
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:\\Users\\Mega Computers\\Pictures\\chris-ried-sqJ40H9RtNw-unsplash.jpg'

# %%
import numpy as np 

for img_name in img_names:
    img_path_full = path + img_name
    img = cv2.imread(img_path_full)
    img = cv2.resize(img , (300 , 200))
    img_2 = np.hstack((img , img ))
    img_4 = np.hstack((img_2 , img_2 ))
    cv2.imshow('4 img ' , img_4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 import numpy as np
# ----> 3 for img_name in img_names:
#       4     img_path_full = path + img_name
#       5     img = cv2.imread(img_path_full)
#
# NameError: name 'img_names' is not defined
